# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

# Parameters (y = a*x + b)
a=0.6
b=2

# Create noisy data
x_data = np.linspace(-10, 10, num=100000)
y_data = a * x_data + b + np.random.normal(size=100000)

# Create the model
model = keras.Sequential()
model.add(keras.layers.Dense(units = 1, activation = 'linear', input_shape=[1]))
model.compile(loss='mse', optimizer="adam")

# Display the model (only 2 parameters to optimize)
model.summary()

# Learn
model.fit( x_data, y_data, epochs=5, verbose=1 )

# Predict (compute) the output
y_predicted = model.predict(x_data)

# Display the result
plt.scatter(x_data[::500], y_data[::500])
plt.plot(x_data, y_predicted, 'r', linewidth=4)
plt.grid()
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 3125/3125 [==============================] - 11s 3ms/step - loss: 6.5909
# Epoch 2/5
# 3125/3125 [==============================] - 10s 3ms/step - loss: 1.0044
# Epoch 3/5
# 3125/3125 [==============================] - 10s 3ms/step - loss: 1.0027
# Epoch 4/5
# 3125/3125 [==============================] - 10s 3ms/step - loss: 1.0027
# Epoch 5/5
# 3125/3125 [==============================] - 10s 3ms/step - loss: 1.0026
# 3125/3125 [==============================] - 9s 3ms/step
